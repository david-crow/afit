# %%
from statsmodels.tsa.stattools import grangercausalitytests as granger
from statsmodels.tsa.stattools import adfuller as adf

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import pickle
import os

# %%
# define adf wrapper
def adf_test(series):
    results = adf(series, autolag="AIC")
    output = pd.Series(results[0:4], index=["Test Statistic", "p-Value", "Lags Used", "Observations Used"])
    
    for k, v in results[4].items():
       output["Critical Value ({})".format(k)] = v

    return output

# %% [markdown]
# ## Grab the data

# %%
stone_dir = "/Users/david/Documents/masters/thesis/data/stone-data"
ornl_dir = "/Users/david/Documents/masters/thesis/data/ornl-data"

# %%
dfs = {}

# for each vehicle, load df from every capture
for d in [stone_dir, ornl_dir]:
    d_dir = os.path.join(d, "pipeline-output")
    print(d_dir)
    
    for v in os.listdir(d_dir):
        v_dir = os.path.join(d_dir, v)

        # skip non-directory junk
        if os.path.isdir(v_dir):
            for c in os.listdir(v_dir):
                c_dir = os.path.join(v_dir, c)

                # skip non-directory junk
                if os.path.isdir(c_dir):
                    path = os.path.join(c_dir, "pickleCombinedDataFrame.p")
                    dfs["{},{},{}".format(d,v,c)] = pickle.load(open(path, "rb"))
# Out:
# /Users/david/Documents/masters/thesis/data/stone-data/pipeline-output
# /Users/david/Documents/masters/thesis/data/ornl-data/pipeline-output

# %%
# plot some example time series
for k in list(dfs.keys())[:1]:
    print(k, "\n")
    
    # get the dataframe
    df = dfs[k]
    times = np.array(df.index)
    
    for s in range(df.shape[1])[:10]:
        print(s, end="\t")
        
        # get the series
        series = df[df.columns[s]].to_numpy()
        
        # augmented dickey-fuller
        results = adf_test(series)
        
        # if the series is stationary...
        if results["Test Statistic"] < results["Critical Value (1%)"]:
            print("(stationary)")
        else:
            print("(not stationary)")
        
        # show the adf results
        print(results)

        # plot the series
        plt.plot(times, series, color="c")

        # plot a subsample of the series
        indices = np.sort(np.random.choice(len(times), size=290))
        plt.plot(times[indices], series[indices], color="m")

        # show it
        plt.show()
# Out:
# /Users/david/Documents/masters/thesis/data/stone-data,honda_accord_2015,0
#
# 0	(stationary)
# Test Statistic             -5.302292
# p-Value                     0.000005
# Lags Used                  47.000000
# Observations Used       25762.000000
# Critical Value (1%)        -3.430604
# Critical Value (5%)        -2.861652
# Critical Value (10%)       -2.566830
# dtype: float64
# 1	(stationary)
# Test Statistic         -6.884306e+00
# p-Value                 1.407370e-09
# Lags Used               4.900000e+01
# Observations Used       2.576000e+04
# Critical Value (1%)    -3.430604e+00
# Critical Value (5%)    -2.861652e+00
# Critical Value (10%)   -2.566830e+00
# dtype: float64
# 2	(stationary)
# Test Statistic         -1.697607e+01
# p-Value                 9.084449e-30
# Lags Used               4.800000e+01
# Observations Used       2.576100e+04
# Critical Value (1%)    -3.430604e+00
# Critical Value (5%)    -2.861652e+00
# Critical Value (10%)   -2.566830e+00
# dtype: float64
# 3	(stationary)
# Test Statistic         -9.927166e+00
# p-Value                 2.886439e-17
# Lags Used               3.700000e+01
# Observations Used       2.577200e+04
# Critical Value (1%)    -3.430604e+00
# Critical Value (5%)    -2.861652e+00
# Critical Value (10%)   -2.566830e+00
# dtype: float64
# 4	(stationary)
# Test Statistic         -1.514321e+01
# p-Value                 6.963247e-28
# Lags Used               4.700000e+01
# Observations Used       2.576200e+04
# Critical Value (1%)    -3.430604e+00
# Critical Value (5%)    -2.861652e+00
# Critical Value (10%)   -2.566830e+00
# dtype: float64
# 5	(stationary)
# Test Statistic         -7.429633e+00
# p-Value                 6.411359e-11
# Lags Used               2.000000e+01
# Observations Used       2.578900e+04
# Critical Value (1%)    -3.430604e+00
# Critical Value (5%)    -2.861652e+00
# Critical Value (10%)   -2.566830e+00
# dtype: float64
# 6	(stationary)
# Test Statistic            -26.145334
# p-Value                     0.000000
# Lags Used                  19.000000
# Observations Used       25790.000000
# Critical Value (1%)        -3.430604
# Critical Value (5%)        -2.861652
# Critical Value (10%)       -2.566830
# dtype: float64
# 7	(not stationary)
# Test Statistic             -0.998012
# p-Value                     0.753989
# Lags Used                  49.000000
# Observations Used       25760.000000
# Critical Value (1%)        -3.430604
# Critical Value (5%)        -2.861652
# Critical Value (10%)       -2.566830
# dtype: float64
# 8	(not stationary)
# Test Statistic             -0.998012
# p-Value                     0.753989
# Lags Used                  49.000000
# Observations Used       25760.000000
# Critical Value (1%)        -3.430604
# Critical Value (5%)        -2.861652
# Critical Value (10%)       -2.566830
# dtype: float64
# 9	(not stationary)
# Test Statistic             12.507059
# p-Value                     1.000000
# Lags Used                  49.000000
# Observations Used       25760.000000
# Critical Value (1%)        -3.430604
# Critical Value (5%)        -2.861652
# Critical Value (10%)       -2.566830
# dtype: float64

# %% [markdown]
# ## Test the granger function

# %%
# generate two random time series
n = 100
times = np.arange(n)
series1 = np.random.normal(size=n)
series2 = np.random.normal(size=n)

# plot them
plt.plot(times, series1)
plt.plot(times, series2)
plt.show()

# use the granger function
test = np.vstack((series1, series2)).T
results = granger(test, maxlag=1)
p_val = results[1][0]["params_ftest"][1]

# check null hypothesis
if p_val < 0.05:
    print("\n{A} Granger causes {B}")
# Out:
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.6115  , p=0.4361  , df_denom=96, df_num=1
# ssr based chi2 test:   chi2=0.6306  , p=0.4271  , df=1
# likelihood ratio test: chi2=0.6286  , p=0.4279  , df=1
# parameter F test:         F=0.6115  , p=0.4361  , df_denom=96, df_num=1

# %%
# grab two time series
df = list(dfs.values())[0]
times = df.index
series1 = df[df.columns[0]].to_numpy()
series2 = df[df.columns[1]].to_numpy()

# plot them
plt.plot(times, series1)
plt.plot(times, series2)
plt.show()

# use the granger function
test = np.vstack((series1, series2)).T
results = granger(test, maxlag=100)
p_val = results[1][0]["params_ftest"][1]

# check null hypothesis
if p_val < 0.05:
    print("\n{A} Granger causes {B}")
# Out:
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.4594  , p=0.4979  , df_denom=25806, df_num=1
# ssr based chi2 test:   chi2=0.4595  , p=0.4979  , df=1
# likelihood ratio test: chi2=0.4595  , p=0.4979  , df=1
# parameter F test:         F=0.4594  , p=0.4979  , df_denom=25806, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.3308  , p=0.7184  , df_denom=25803, df_num=2
# ssr based chi2 test:   chi2=0.6617  , p=0.7183  , df=2
# likelihood ratio test: chi2=0.6616  , p=0.7183  , df=2
# parameter F test:         F=0.3308  , p=0.7184  , df_denom=25803, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.2105  , p=0.8892  , df_denom=25800, df_num=3
# ssr based chi2 test:   chi2=0.6317  , p=0.8891  , df=3
# likelihood ratio test: chi2=0.6317  , p=0.8891  , df=3
# parameter F test:         F=0.2105  , p=0.8892  , df_denom=25800, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.6374  , p=0.6358  , df_denom=25797, df_num=4
# ssr based chi2 test:   chi2=2.5505  , p=0.6356  , df=4
# likelihood ratio test: chi2=2.5504  , p=0.6356  , df=4
# parameter F test:         F=0.6374  , p=0.6358  , df_denom=25797, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=0.3950  , p=0.8526  , df_denom=25794, df_num=5
# ssr based chi2 test:   chi2=1.9760  , p=0.8525  , df=5
# likelihood ratio test: chi2=1.9759  , p=0.8525  , df=5
# parameter F test:         F=0.3950  , p=0.8526  , df_denom=25794, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.3995  , p=0.8798  , df_denom=25791, df_num=6
# ssr based chi2 test:   chi2=2.3984  , p=0.8797  , df=6
# likelihood ratio test: chi2=2.3983  , p=0.8797  , df=6
# parameter F test:         F=0.3995  , p=0.8798  , df_denom=25791, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=0.3440  , p=0.9339  , df_denom=25788, df_num=7
# ssr based chi2 test:   chi2=2.4093  , p=0.9338  , df=7
# likelihood ratio test: chi2=2.4092  , p=0.9338  , df=7
# parameter F test:         F=0.3440  , p=0.9339  , df_denom=25788, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=0.5619  , p=0.8099  , df_denom=25785, df_num=8
# ssr based chi2 test:   chi2=4.4981  , p=0.8096  , df=8
# likelihood ratio test: chi2=4.4977  , p=0.8097  , df=8
# parameter F test:         F=0.5619  , p=0.8099  , df_denom=25785, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=0.5461  , p=0.8416  , df_denom=25782, df_num=9
# ssr based chi2 test:   chi2=4.9188  , p=0.8413  , df=9
# likelihood ratio test: chi2=4.9183  , p=0.8414  , df=9
# parameter F test:         F=0.5461  , p=0.8416  , df_denom=25782, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=0.4915  , p=0.8968  , df_denom=25779, df_num=10
# ssr based chi2 test:   chi2=4.9190  , p=0.8965  , df=10
# likelihood ratio test: chi2=4.9185  , p=0.8966  , df=10
# parameter F test:         F=0.4915  , p=0.8968  , df_denom=25779, df_num=10
#
# Granger Causality
# number of lags (no zero) 11
# ssr based F test:         F=0.5019  , p=0.9033  , df_denom=25776, df_num=11
# ssr based chi2 test:   chi2=5.5262  , p=0.9030  , df=11
# likelihood ratio test: chi2=5.5256  , p=0.9031  , df=11
# parameter F test:         F=0.5019  , p=0.9033  , df_denom=25776, df_num=11
#
# Granger Causality
# number of lags (no zero) 12
# ssr based F test:         F=0.7386  , p=0.7146  , df_denom=25773, df_num=12
# ssr based chi2 test:   chi2=8.8717  , p=0.7139  , df=12
# likelihood ratio test: chi2=8.8701  , p=0.7140  , df=12
# parameter F test:         F=0.7386  , p=0.7146  , df_denom=25773, df_num=12
#
# Granger Causality
# number of lags (no zero) 13
# ssr based F test:         F=0.7774  , p=0.6852  , df_denom=25770, df_num=13
# ssr based chi2 test:   chi2=10.1168 , p=0.6844  , df=13
# likelihood ratio test: chi2=10.1148 , p=0.6845  , df=13
# parameter F test:         F=0.7774  , p=0.6852  , df_denom=25770, df_num=13
#
# Granger Causality
# number of lags (no zero) 14
# ssr based F test:         F=0.7258  , p=0.7503  , df_denom=25767, df_num=14
# ssr based chi2 test:   chi2=10.1719 , p=0.7495  , df=14
# likelihood ratio test: chi2=10.1699 , p=0.7497  , df=14
# parameter F test:         F=0.7258  , p=0.7503  , df_denom=25767, df_num=14
#
# Granger Causality
# number of lags (no zero) 15
# ssr based F test:         F=0.8214  , p=0.6545  , df_denom=25764, df_num=15
# ssr based chi2 test:   chi2=12.3362 , p=0.6534  , df=15
# likelihood ratio test: chi2=12.3333 , p=0.6536  , df=15
# parameter F test:         F=0.8214  , p=0.6545  , df_denom=25764, df_num=15
#
# Granger Causality
# number of lags (no zero) 16
# ssr based F test:         F=0.8111  , p=0.6743  , df_denom=25761, df_num=16
# ssr based chi2 test:   chi2=12.9949 , p=0.6731  , df=16
# likelihood ratio test: chi2=12.9916 , p=0.6734  , df=16
# parameter F test:         F=0.8111  , p=0.6743  , df_denom=25761, df_num=16
#
# Granger Causality
# number of lags (no zero) 17
# ssr based F test:         F=0.8030  , p=0.6916  , df_denom=25758, df_num=17
# ssr based chi2 test:   chi2=13.6700 , p=0.6903  , df=17
# likelihood ratio test: chi2=13.6664 , p=0.6906  , df=17
# parameter F test:         F=0.8030  , p=0.6916  , df_denom=25758, df_num=17
#
# Granger Causality
# number of lags (no zero) 18
# ssr based F test:         F=0.8263  , p=0.6706  , df_denom=25755, df_num=18
# ssr based chi2 test:   chi2=14.8950 , p=0.6692  , df=18
# likelihood ratio test: chi2=14.8907 , p=0.6695  , df=18
# parameter F test:         F=0.8263  , p=0.6706  , df_denom=25755, df_num=18
#
# Granger Causality
# number of lags (no zero) 19
# ssr based F test:         F=0.7661  , p=0.7503  , df_denom=25752, df_num=19
# ssr based chi2 test:   chi2=14.5787 , p=0.7490  , df=19
# likelihood ratio test: chi2=14.5746 , p=0.7492  , df=19
# parameter F test:         F=0.7661  , p=0.7503  , df_denom=25752, df_num=19
#
# Granger Causality
# number of lags (no zero) 20
# ssr based F test:         F=0.7727  , p=0.7498  , df_denom=25749, df_num=20
# ssr based chi2 test:   chi2=15.4790 , p=0.7484  , df=20
# likelihood ratio test: chi2=15.4743 , p=0.7487  , df=20
# parameter F test:         F=0.7727  , p=0.7498  , df_denom=25749, df_num=20
#
# Granger Causality
# number of lags (no zero) 21
# ssr based F test:         F=0.7361  , p=0.7993  , df_denom=25746, df_num=21
# ssr based chi2 test:   chi2=15.4830 , p=0.7980  , df=21
# likelihood ratio test: chi2=15.4783 , p=0.7982  , df=21
# parameter F test:         F=0.7361  , p=0.7993  , df_denom=25746, df_num=21
#
# Granger Causality
# number of lags (no zero) 22
# ssr based F test:         F=0.6894  , p=0.8549  , df_denom=25743, df_num=22
# ssr based chi2 test:   chi2=15.1944 , p=0.8538  , df=22
# likelihood ratio test: chi2=15.1899 , p=0.8540  , df=22
# parameter F test:         F=0.6894  , p=0.8549  , df_denom=25743, df_num=22
#
# Granger Causality
# number of lags (no zero) 23
# ssr based F test:         F=0.7694  , p=0.7737  , df_denom=25740, df_num=23
# ssr based chi2 test:   chi2=17.7283 , p=0.7721  , df=23
# likelihood ratio test: chi2=17.7222 , p=0.7724  , df=23
# parameter F test:         F=0.7694  , p=0.7737  , df_denom=25740, df_num=23
#
# Granger Causality
# number of lags (no zero) 24
# ssr based F test:         F=0.7291  , p=0.8266  , df_denom=25737, df_num=24
# ssr based chi2 test:   chi2=17.5317 , p=0.8251  , df=24
# likelihood ratio test: chi2=17.5257 , p=0.8254  , df=24
# parameter F test:         F=0.7291  , p=0.8266  , df_denom=25737, df_num=24
#
# Granger Causality
# number of lags (no zero) 25
# ssr based F test:         F=0.8141  , p=0.7281  , df_denom=25734, df_num=25
# ssr based chi2 test:   chi2=20.3919 , p=0.7260  , df=25
# likelihood ratio test: chi2=20.3839 , p=0.7264  , df=25
# parameter F test:         F=0.8141  , p=0.7281  , df_denom=25734, df_num=25
#
# Granger Causality
# number of lags (no zero) 26
# ssr based F test:         F=0.7887  , p=0.7669  , df_denom=25731, df_num=26
# ssr based chi2 test:   chi2=20.5480 , p=0.7649  , df=26
# likelihood ratio test: chi2=20.5398 , p=0.7653  , df=26
# parameter F test:         F=0.7887  , p=0.7669  , df_denom=25731, df_num=26
#
# Granger Causality
# number of lags (no zero) 27
# ssr based F test:         F=0.7516  , p=0.8181  , df_denom=25728, df_num=27
# ssr based chi2 test:   chi2=20.3373 , p=0.8163  , df=27
# likelihood ratio test: chi2=20.3293 , p=0.8167  , df=27
# parameter F test:         F=0.7516  , p=0.8181  , df_denom=25728, df_num=27
#
# Granger Causality
# number of lags (no zero) 28
# ssr based F test:         F=0.7289  , p=0.8490  , df_denom=25725, df_num=28
# ssr based chi2 test:   chi2=20.4558 , p=0.8473  , df=28
# likelihood ratio test: chi2=20.4477 , p=0.8476  , df=28
# parameter F test:         F=0.7289  , p=0.8490  , df_denom=25725, df_num=28
#
# Granger Causality
# number of lags (no zero) 29
# ssr based F test:         F=0.9468  , p=0.5471  , df_denom=25722, df_num=29
# ssr based chi2 test:   chi2=27.5202 , p=0.5437  , df=29
# likelihood ratio test: chi2=27.5055 , p=0.5445  , df=29
# parameter F test:         F=0.9468  , p=0.5471  , df_denom=25722, df_num=29
#
# Granger Causality
# number of lags (no zero) 30
# ssr based F test:         F=0.9440  , p=0.5536  , df_denom=25719, df_num=30
# ssr based chi2 test:   chi2=28.3860 , p=0.5500  , df=30
# likelihood ratio test: chi2=28.3704 , p=0.5508  , df=30
# parameter F test:         F=0.9440  , p=0.5536  , df_denom=25719, df_num=30
#
# Granger Causality
# number of lags (no zero) 31
# ssr based F test:         F=1.0283  , p=0.4228  , df_denom=25716, df_num=31
# ssr based chi2 test:   chi2=31.9554 , p=0.4189  , df=31
# likelihood ratio test: chi2=31.9356 , p=0.4199  , df=31
# parameter F test:         F=1.0283  , p=0.4228  , df_denom=25716, df_num=31
#
# Granger Causality
# number of lags (no zero) 32
# ssr based F test:         F=1.0057  , p=0.4577  , df_denom=25713, df_num=32
# ssr based chi2 test:   chi2=32.2647 , p=0.4537  , df=32
# likelihood ratio test: chi2=32.2445 , p=0.4547  , df=32
# parameter F test:         F=1.0057  , p=0.4577  , df_denom=25713, df_num=32
#
# Granger Causality
# number of lags (no zero) 33
# ssr based F test:         F=1.0482  , p=0.3919  , df_denom=25710, df_num=33
# ssr based chi2 test:   chi2=34.6820 , p=0.3876  , df=33
# likelihood ratio test: chi2=34.6587 , p=0.3887  , df=33
# parameter F test:         F=1.0482  , p=0.3919  , df_denom=25710, df_num=33
#
# Granger Causality
# number of lags (no zero) 34
# ssr based F test:         F=1.0193  , p=0.4366  , df_denom=25707, df_num=34
# ssr based chi2 test:   chi2=34.7486 , p=0.4321  , df=34
# likelihood ratio test: chi2=34.7252 , p=0.4332  , df=34
# parameter F test:         F=1.0193  , p=0.4366  , df_denom=25707, df_num=34
#
# Granger Causality
# number of lags (no zero) 35
# ssr based F test:         F=1.0057  , p=0.4588  , df_denom=25704, df_num=35
# ssr based chi2 test:   chi2=35.2975 , p=0.4541  , df=35
# likelihood ratio test: chi2=35.2733 , p=0.4553  , df=35
# parameter F test:         F=1.0057  , p=0.4588  , df_denom=25704, df_num=35
#
# Granger Causality
# number of lags (no zero) 36
# ssr based F test:         F=1.0318  , p=0.4161  , df_denom=25701, df_num=36
# ssr based chi2 test:   chi2=37.2517 , p=0.4113  , df=36
# likelihood ratio test: chi2=37.2248 , p=0.4125  , df=36
# parameter F test:         F=1.0318  , p=0.4161  , df_denom=25701, df_num=36
#
# Granger Causality
# number of lags (no zero) 37
# ssr based F test:         F=1.0869  , p=0.3299  , df_denom=25698, df_num=37
# ssr based chi2 test:   chi2=40.3327 , p=0.3251  , df=37
# likelihood ratio test: chi2=40.3012 , p=0.3264  , df=37
# parameter F test:         F=1.0869  , p=0.3299  , df_denom=25698, df_num=37
#
# Granger Causality
# number of lags (no zero) 38
# ssr based F test:         F=1.0623  , p=0.3662  , df_denom=25695, df_num=38
# ssr based chi2 test:   chi2=40.4877 , p=0.3611  , df=38
# likelihood ratio test: chi2=40.4559 , p=0.3624  , df=38
# parameter F test:         F=1.0623  , p=0.3662  , df_denom=25695, df_num=38
#
# Granger Causality
# number of lags (no zero) 39
# ssr based F test:         F=1.0480  , p=0.3884  , df_denom=25692, df_num=39
# ssr based chi2 test:   chi2=40.9965 , p=0.3830  , df=39
# likelihood ratio test: chi2=40.9639 , p=0.3844  , df=39
# parameter F test:         F=1.0480  , p=0.3884  , df_denom=25692, df_num=39
#
# Granger Causality
# number of lags (no zero) 40
# ssr based F test:         F=1.0529  , p=0.3796  , df_denom=25689, df_num=40
# ssr based chi2 test:   chi2=42.2500 , p=0.3740  , df=40
# likelihood ratio test: chi2=42.2154 , p=0.3754  , df=40
# parameter F test:         F=1.0529  , p=0.3796  , df_denom=25689, df_num=40
#
# Granger Causality
# number of lags (no zero) 41
# ssr based F test:         F=1.0402  , p=0.4002  , df_denom=25686, df_num=41
# ssr based chi2 test:   chi2=42.7862 , p=0.3944  , df=41
# likelihood ratio test: chi2=42.7508 , p=0.3959  , df=41
# parameter F test:         F=1.0402  , p=0.4002  , df_denom=25686, df_num=41
#
# Granger Causality
# number of lags (no zero) 42
# ssr based F test:         F=1.1232  , p=0.2696  , df_denom=25683, df_num=42
# ssr based chi2 test:   chi2=47.3286 , p=0.2642  , df=42
# likelihood ratio test: chi2=47.2852 , p=0.2656  , df=42
# parameter F test:         F=1.1232  , p=0.2696  , df_denom=25683, df_num=42
#
# Granger Causality
# number of lags (no zero) 43
# ssr based F test:         F=1.1011  , p=0.2999  , df_denom=25680, df_num=43
# ssr based chi2 test:   chi2=47.5075 , p=0.2941  , df=43
# likelihood ratio test: chi2=47.4638 , p=0.2956  , df=43
# parameter F test:         F=1.1011  , p=0.2999  , df_denom=25680, df_num=43
#
# Granger Causality
# number of lags (no zero) 44
# ssr based F test:         F=1.0734  , p=0.3422  , df_denom=25677, df_num=44
# ssr based chi2 test:   chi2=47.3930 , p=0.3360  , df=44
# likelihood ratio test: chi2=47.3495 , p=0.3376  , df=44
# parameter F test:         F=1.0734  , p=0.3422  , df_denom=25677, df_num=44
#
# Granger Causality
# number of lags (no zero) 45
# ssr based F test:         F=1.0566  , p=0.3695  , df_denom=25674, df_num=45
# ssr based chi2 test:   chi2=47.7152 , p=0.3629  , df=45
# likelihood ratio test: chi2=47.6711 , p=0.3646  , df=45
# parameter F test:         F=1.0566  , p=0.3695  , df_denom=25674, df_num=45
#
# Granger Causality
# number of lags (no zero) 46
# ssr based F test:         F=1.0480  , p=0.3838  , df_denom=25671, df_num=46
# ssr based chi2 test:   chi2=48.3836 , p=0.3769  , df=46
# likelihood ratio test: chi2=48.3382 , p=0.3786  , df=46
# parameter F test:         F=1.0480  , p=0.3838  , df_denom=25671, df_num=46
#
# Granger Causality
# number of lags (no zero) 47
# ssr based F test:         F=1.0301  , p=0.4156  , df_denom=25668, df_num=47
# ssr based chi2 test:   chi2=48.5961 , p=0.4085  , df=47
# likelihood ratio test: chi2=48.5503 , p=0.4103  , df=47
# parameter F test:         F=1.0301  , p=0.4156  , df_denom=25668, df_num=47
#
# Granger Causality
# number of lags (no zero) 48
# ssr based F test:         F=0.9911  , p=0.4903  , df_denom=25665, df_num=48
# ssr based chi2 test:   chi2=47.7533 , p=0.4829  , df=48
# likelihood ratio test: chi2=47.7091 , p=0.4847  , df=48
# parameter F test:         F=0.9911  , p=0.4903  , df_denom=25665, df_num=48
#
# Granger Causality
# number of lags (no zero) 49
# ssr based F test:         F=0.9767  , p=0.5195  , df_denom=25662, df_num=49
# ssr based chi2 test:   chi2=48.0409 , p=0.5120  , df=49
# likelihood ratio test: chi2=47.9962 , p=0.5138  , df=49
# parameter F test:         F=0.9767  , p=0.5195  , df_denom=25662, df_num=49
#
# Granger Causality
# number of lags (no zero) 50
# ssr based F test:         F=0.9727  , p=0.5283  , df_denom=25659, df_num=50
# ssr based chi2 test:   chi2=48.8253 , p=0.5206  , df=50
# likelihood ratio test: chi2=48.7791 , p=0.5224  , df=50
# parameter F test:         F=0.9727  , p=0.5283  , df_denom=25659, df_num=50
#
# Granger Causality
# number of lags (no zero) 51
# ssr based F test:         F=0.9607  , p=0.5537  , df_denom=25656, df_num=51
# ssr based chi2 test:   chi2=49.1910 , p=0.5458  , df=51
# likelihood ratio test: chi2=49.1441 , p=0.5477  , df=51
# parameter F test:         F=0.9607  , p=0.5537  , df_denom=25656, df_num=51
#
# Granger Causality
# number of lags (no zero) 52
# ssr based F test:         F=0.9426  , p=0.5920  , df_denom=25653, df_num=52
# ssr based chi2 test:   chi2=49.2153 , p=0.5841  , df=52
# likelihood ratio test: chi2=49.1683 , p=0.5860  , df=52
# parameter F test:         F=0.9426  , p=0.5920  , df_denom=25653, df_num=52
#
# Granger Causality
# number of lags (no zero) 53
# ssr based F test:         F=0.9424  , p=0.5938  , df_denom=25650, df_num=53
# ssr based chi2 test:   chi2=50.1546 , p=0.5856  , df=53
# likelihood ratio test: chi2=50.1059 , p=0.5876  , df=53
# parameter F test:         F=0.9424  , p=0.5938  , df_denom=25650, df_num=53
#
# Granger Causality
# number of lags (no zero) 54
# ssr based F test:         F=0.9269  , p=0.6274  , df_denom=25647, df_num=54
# ssr based chi2 test:   chi2=50.2635 , p=0.6193  , df=54
# likelihood ratio test: chi2=50.2145 , p=0.6212  , df=54
# parameter F test:         F=0.9269  , p=0.6274  , df_denom=25647, df_num=54
#
# Granger Causality
# number of lags (no zero) 55
# ssr based F test:         F=0.9931  , p=0.4892  , df_denom=25644, df_num=55
# ssr based chi2 test:   chi2=54.8559 , p=0.4801  , df=55
# likelihood ratio test: chi2=54.7975 , p=0.4823  , df=55
# parameter F test:         F=0.9931  , p=0.4892  , df_denom=25644, df_num=55
#
# Granger Causality
# number of lags (no zero) 56
# ssr based F test:         F=0.9877  , p=0.5011  , df_denom=25641, df_num=56
# ssr based chi2 test:   chi2=55.5522 , p=0.4918  , df=56
# likelihood ratio test: chi2=55.4924 , p=0.4940  , df=56
# parameter F test:         F=0.9877  , p=0.5011  , df_denom=25641, df_num=56
#
# Granger Causality
# number of lags (no zero) 57
# ssr based F test:         F=0.9812  , p=0.5154  , df_denom=25638, df_num=57
# ssr based chi2 test:   chi2=56.1773 , p=0.5059  , df=57
# likelihood ratio test: chi2=56.1161 , p=0.5082  , df=57
# parameter F test:         F=0.9812  , p=0.5154  , df_denom=25638, df_num=57
#
# Granger Causality
# number of lags (no zero) 58
# ssr based F test:         F=0.9668  , p=0.5473  , df_denom=25635, df_num=58
# ssr based chi2 test:   chi2=56.3293 , p=0.5377  , df=58
# likelihood ratio test: chi2=56.2678 , p=0.5400  , df=58
# parameter F test:         F=0.9668  , p=0.5473  , df_denom=25635, df_num=58
#
# Granger Causality
# number of lags (no zero) 59
# ssr based F test:         F=0.9507  , p=0.5834  , df_denom=25632, df_num=59
# ssr based chi2 test:   chi2=56.3496 , p=0.5738  , df=59
# likelihood ratio test: chi2=56.2881 , p=0.5761  , df=59
# parameter F test:         F=0.9507  , p=0.5834  , df_denom=25632, df_num=59
#
# Granger Causality
# number of lags (no zero) 60
# ssr based F test:         F=0.9427  , p=0.6021  , df_denom=25629, df_num=60
# ssr based chi2 test:   chi2=56.8290 , p=0.5923  , df=60
# likelihood ratio test: chi2=56.7663 , p=0.5946  , df=60
# parameter F test:         F=0.9427  , p=0.6021  , df_denom=25629, df_num=60
#
# Granger Causality
# number of lags (no zero) 61
# ssr based F test:         F=1.0209  , p=0.4307  , df_denom=25626, df_num=61
# ssr based chi2 test:   chi2=62.5739 , p=0.4201  , df=61
# likelihood ratio test: chi2=62.4980 , p=0.4228  , df=61
# parameter F test:         F=1.0209  , p=0.4307  , df_denom=25626, df_num=61
#
# Granger Causality
# number of lags (no zero) 62
# ssr based F test:         F=1.0062  , p=0.4626  , df_denom=25623, df_num=62
# ssr based chi2 test:   chi2=62.6877 , p=0.4517  , df=62
# likelihood ratio test: chi2=62.6115 , p=0.4544  , df=62
# parameter F test:         F=1.0062  , p=0.4626  , df_denom=25623, df_num=62
#
# Granger Causality
# number of lags (no zero) 63
# ssr based F test:         F=1.0028  , p=0.4702  , df_denom=25620, df_num=63
# ssr based chi2 test:   chi2=63.4896 , p=0.4590  , df=63
# likelihood ratio test: chi2=63.4115 , p=0.4618  , df=63
# parameter F test:         F=1.0028  , p=0.4702  , df_denom=25620, df_num=63
#
# Granger Causality
# number of lags (no zero) 64
# ssr based F test:         F=0.9905  , p=0.4981  , df_denom=25617, df_num=64
# ssr based chi2 test:   chi2=63.7099 , p=0.4867  , df=64
# likelihood ratio test: chi2=63.6312 , p=0.4895  , df=64
# parameter F test:         F=0.9905  , p=0.4981  , df_denom=25617, df_num=64
#
# Granger Causality
# number of lags (no zero) 65
# ssr based F test:         F=0.9804  , p=0.5215  , df_denom=25614, df_num=65
# ssr based chi2 test:   chi2=64.0535 , p=0.5099  , df=65
# likelihood ratio test: chi2=63.9739 , p=0.5127  , df=65
# parameter F test:         F=0.9804  , p=0.5215  , df_denom=25614, df_num=65
#
# Granger Causality
# number of lags (no zero) 66

# %%
for idx, i in enumerate(list(dfs.keys())):
    print("{}: {}".format(idx, i))
