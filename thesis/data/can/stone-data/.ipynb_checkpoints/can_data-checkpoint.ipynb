# %%
import pandas as pd
import numpy as np

import time
import sys
import os

# %%
metadata = pd.read_csv("metadata.csv")
display(metadata)
# Out:
#     Capture       Make      Model  Year
# 0       101  Chevrolet     Cobalt  2009
# 1       102  Chevrolet  Silverado  2011
# 2       103      Dodge       1500  2014
# 3       104       Ford      F-150  2017
# 4       105       Ford      Focus  2010
# 5       106      Honda     Accord  2012
# 6       107      Honda     Accord  2015
# 7       108     Nissan       370Z  2015
# 8       109     Nissan     XTERRA  2010
# 9       110       Saab       9-7X  2009
# 10      111     Toyota    Corolla  2009

# %%
# how long does this take?
start = time.time()

# make the output file
output = open("can_data.csv", "w+")
output.write("captureid,vehicle_id,ts,arbitration_id,dlc,data,make,model,year\n")

# for every vehicle...
for i in metadata["Capture"].unique():
    vehicle_start = time.time()
    print("Starting vehicle {}...".format(i), end="\t")
    
    f = open("temp/loggerProgram{}.log".format(i), "r")
    f.readline() # ignore the header

    # for every message...
    for line in f:
        # remove white space and the timestamp's ":"
        line = line.split()
        line[0] = line[0][:-1]
        
        # because sometimes pandas indices don't line up
        meta = metadata[metadata["Capture"] == i]
        
        # build the output string
        out = [
            str(i),                     # captureid
            str(i),                     # vehicle_id
            str(line[0]),               # timestamp
            str(line[1]).upper(),       # arbID
            str(line[2]),               # dlc
            "".join(line[3:]).upper(),  # data
            str(meta["Make"].iloc[0]),  # make
            str(meta["Model"].iloc[0]), # model
            str(meta["Year"].iloc[0])   # year
        ]
        
        # write to the file
        output.write(",".join(out) + "\n")

    f.close()
    vehicle_elapsed = time.time() - vehicle_start
    print("Done! Elapsed: {:.2f} seconds ({:.2f} minutes)".format(vehicle_elapsed, vehicle_elapsed / 60))

# output.close()
elapsed = time.time() - start
print("Elapsed time: {:.2f} seconds ({:.2f} minutes)".format(elapsed, elapsed / 60))
# Out:
# Starting vehicle 101...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-fb1abc379db1> in <module>
#      20
#      21         # because sometimes pandas indices don't line up
# ---> 22         meta = metadata[metadata["Capture"] == i]
#      23
#      24         # build the output string
#
# ~/anaconda3/envs/can/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2916         # Do we have a (boolean) 1d indexer?
#    2917         if com.is_bool_indexer(key):
# -> 2918             return self._getitem_bool_array(key)
#    2919
#    2920         # We are left with two options: a single key, and a collection of keys,
#
# ~/anaconda3/envs/can/lib/python3.7/site-packages/pandas/core/frame.py in _getitem_bool_array(self, key)
#    2967         key = check_bool_indexer(self.index, key)
#    2968         indexer = key.nonzero()[0]
# -> 2969         return self._take(indexer, axis=0)
#    2970
#    2971     def _getitem_multilevel(self, key):
#
# ~/anaconda3/envs/can/lib/python3.7/site-packages/pandas/core/generic.py in _take(self, indices, axis, is_copy)
#    3357         new_data = self._data.take(indices,
#    3358                                    axis=self._get_block_manager_axis(axis),
# -> 3359                                    verify=True)
#    3360         result = self._constructor(new_data).__finalize__(self)
#    3361
#
# ~/anaconda3/envs/can/lib/python3.7/site-packages/pandas/core/internals/managers.py in take(self, indexer, axis, verify, convert)
#    1348         new_labels = self.axes[axis].take(indexer)
#    1349         return self.reindex_indexer(new_axis=new_labels, indexer=indexer,
# -> 1350                                     axis=axis, allow_dups=True)
#    1351
#    1352     def merge(self, other, lsuffix='', rsuffix=''):
#
# ~/anaconda3/envs/can/lib/python3.7/site-packages/pandas/core/internals/managers.py in reindex_indexer(self, new_axis, indexer, axis, fill_value, allow_dups, copy)
#    1233             new_blocks = [blk.take_nd(indexer, axis=axis, fill_tuple=(
#    1234                 fill_value if fill_value is not None else blk.fill_value,))
# -> 1235                 for blk in self.blocks]
#    1236
#    1237         new_axes = list(self.axes)
#
# ~/anaconda3/envs/can/lib/python3.7/site-packages/pandas/core/internals/managers.py in <listcomp>(.0)
#    1233             new_blocks = [blk.take_nd(indexer, axis=axis, fill_tuple=(
#    1234                 fill_value if fill_value is not None else blk.fill_value,))
# -> 1235                 for blk in self.blocks]
#    1236
#    1237         new_axes = list(self.axes)
#
# ~/anaconda3/envs/can/lib/python3.7/site-packages/pandas/core/internals/blocks.py in take_nd(self, indexer, axis, new_mgr_locs, fill_tuple)
#    1251             return self.make_block(new_values, new_mgr_locs)
#    1252         else:
# -> 1253             return self.make_block_same_class(new_values, new_mgr_locs)
#    1254
#    1255     def diff(self, n, axis=1):
#
# ~/anaconda3/envs/can/lib/python3.7/site-packages/pandas/core/internals/blocks.py in make_block_same_class(self, values, placement, ndim, dtype)
#     232         if placement is None:
#     233             placement = self.mgr_locs
# --> 234         return make_block(values, placement=placement, ndim=ndim,
#     235                           klass=self.__class__, dtype=dtype)
#     236
#
# KeyboardInterrupt:
