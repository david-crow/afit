# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
x = np.arange(1, 11, 1)

det = [
    0.168319,
    0.700000,
    0.413514,
    0.426602,
    0.716667,
    0.474632,
    0.177236,
    0.521721,
    0.000000,  # "Did not finish"
    0.350254
]

sto = [
    -1.509787,
    0.120098,
    -0.486486,
    -2.799535,
    -2.337500,
    -0.152573,
    -4.085834,
    -1.095355,
    -1.936070,
    -1.892918
]

loc = [
    0.168318,
    0.700000,
    0.413513,
    0.426602,
    0.716666,
    0.271139,
    -0.313384,
    -0.018886,
    -0.382878,
    0.350254
]

det = np.array(det)
sto = np.array(sto)
loc = np.array(loc)

# %%
fig, ax = plt.subplots(1, 1, figsize=(15, 15))

ax.set_xlabel("Problem Number", fontsize=20)
ax.set_ylabel("Value of Returned Solution", fontsize=20)
ax.tick_params(axis="both", which="major", labelsize=20)

ax.set_xlim(0.5, 10.5)
ax.set_xticks(np.arange(1, 11, 1))

ax.bar(x - 0.25, det, width=0.25, label="Deterministic")
ax.bar(x + 0.00, sto, width=0.25, label="Stochastic")
ax.bar(x + 0.25, loc, width=0.25, label="Local")
ax.plot([0.5, 10.5], [0, 0], color="k")
ax.annotate("X", xy=(8.605, -0.08), color="red", fontsize=35)

ax.legend(fontsize=20, loc=4)
display(ax)

plt.savefig("report/figures/bar-chart.png")
